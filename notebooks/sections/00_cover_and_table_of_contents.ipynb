# %% [markdown]
# <h1><strong>Programming for Data Analytics CA1 Assignment</strong></h1>
# <p>Full Name: <strong><u>Goh Kun Ming</u></strong><br/>Admin Number: <strong><u>P2415691</u></strong><br/>Class: <strong><u>DAAA/FT/1B/02</u></strong></p>

# %% [markdown]
# # Table of Contents
#
# - [1. Introduction and Research Context](#1.-Introduction-and-Research-Context)
#     - [1.1 Background Information](#1.1-Background-Information)
#     - [1.2 Research Question](#1.2-Research-Question)
#     - [1.3 Research Objectives](#1.3-Research-Objectives)
#
# - [2. Data Preparation and Cleaning](#2.-Data-Preparation-and-Cleaning)
#     - [2.1 Importing of Packages](#2.1-Importing-of-Packages)
#     - [2.2 Data Overview](#2.2-Data-Overview)
#       - [2.2.1 First Dataset](#2.2.1-First-Dataset)
#         - [2.2.1.1 First Dataset's Content](#2.2.1.1-First-Dataset's-Content)
#         - [2.2.1.2 First Dataset's Shape](#2.2.1.2-First-Dataset's-Shape)
#         - [2.2.1.3 First Dataset's Missing Data](#2.2.1.3-First-Dataset's-Missing-Data)
#       - [2.2.2 Second Dataset](#2.2.2-Second-Dataset)
#         - [2.2.2.1 Second Dataset's Content](#2.2.2.1-Second-Dataset's-Content)
#         - [2.2.2.2 Second Dataset's Shape](#2.2.2.2-Second-Dataset's-Shape)
#         - [2.2.2.3 Second Dataset's Missing Data](#2.2.2.3-Second-Dataset's-Missing-Data)
#       - [2.2.3 Third Dataset](#2.2.3-Third-Dataset)
#         - [2.2.3.1 Third Dataset's Content](#2.2.3.1-Third-Dataset's-Content)
#         - [2.2.3.2 Third Dataset's Shape](#2.2.3.2-Third-Dataset's-Shape)
#         - [2.2.3.3 Third Dataset's Missing Data](#2.2.3.3-Third-Dataset's-Missing-Data)
#       - [2.2.4 Fourth Dataset](#2.2.4-Fourth-Dataset)
#         - [2.2.4.1 Fourth Dataset's Content](#2.2.4.1-Fourth-Dataset's-Content)
#         - [2.2.4.2 Fourth Dataset's Shape](#2.2.4.2-Fourth-Dataset's-Shape)
#         - [2.2.4.3 Fourth Dataset's Missing Data](#2.2.4.3-Fourth-Dataset's-Missing-Data)
#       - [2.2.5 Fifth Dataset](#2.2.5-Fourth-Dataset)
#         - [2.2.5.1 Fifth Dataset's Content](#2.2.5.1-Fifth-Dataset's-Content)
#         - [2.2.5.2 Fifth Dataset's Shape](#2.2.5.2-Fifth-Dataset's-Shape)
#         - [2.2.5.3 Fifth Dataset's Missing Data](#2.2.5.3-Fifth-Dataset's-Missing-Data)
#     - [2.3 Merging and Filtering Dataset](#2.3-Merging-and-Filtering-Dataset)
#     - [2.4 Imputing Missing Data](#2.4-Imputing-Missing-Data)
#       - [2.4.1 Identifying Missing Data](#2.4.1-Identifying-Missing-Data)
#       - [2.4.2 Imputation of Missing Data](#2.4.2-Imputation-of-Missing-Data)
#     - [2.5 Handling Duplicated Data](#2.5-Handling-Duplicated-Data)
#       - [2.5.1 Identifying Duplicated Data](#2.5.1-Identifying-Duplicated-Data)
#       - [2.5.2 Removing Duplicated Data](#2.5.2-Removing-Duplicated-Data)
#     - [2.6 Fixing Data Types](#2.6-Fixing-Data-Types)
#       - [2.6.1 Identifying Potential Incorrect Data Types](#2.6.1-Identifying-Potential-Incorrect-Data-Types)
#       - [2.6.2 Addressing Incorrect and Unsuitable Data Types](#2.6.2-Addressing-Incorrect-and-Unsuitable-Data-Types)
#     - [2.7 Standardising Categorical Data](#2.7-Standardising-Categorical-Data)
#       - [2.7.1 Identifying Types of Pay Period](#2.7.1-Identifying-Types-of-Pay-Period)
#       - [2.7.2 Standardisation of Pay Period Format](#2.7.2-Standardisation-of-Pay-Period-Format)
#     - [2.8 Feature Engineering](#2.8-Feature-Engineering)
#     - [2.9 Handling Outliers](#2.9-Handling-Outliers)
#       - [2.9.1 Handling Outliers Using IQR Method](#2.9.1-Handling-Outliers-Using-IQR-Method)
#           - [2.9.1.1 Identifying Outliers Using IQR Method For Maximum Salary](#2.9.1.1-Identifying-Outliers-Using-IQR-Method-For-Maximum-Salary)
#           - [2.9.1.2 Identifying Outliers Using IQR Method For Minimum Salary](#2.9.1.2-Identifying-Outliers-Using-IQR-Method-For-Minimum-Salary)
#           - [2.9.1.3 Identifying Outliers Using IQR Method For Salary Range](#2.9.1.3-Identifying-Outliers-Using-IQR-Method-For-Salary-Range)
#           - [2.9.1.4 Removing Identified Outliers Using IQR Method](#2.9.1.4-Removing-Identified-Outliers-Using-IQR-Method)
#       - [2.9.2 Handling Outliers Using Z-Score](#2.9.2-Handling-Outliers-Using-Z-Score)
#           - [2.9.2.1 Identifying Outliers Using Z-Score For Maximum Salary](#2.9.2.1-Identifying-Outliers-Using-Z-Score-For-Maximum-Salary)
#           - [2.9.2.2 Identifying Outliers Using Z-Score For Minimum Salary](#2.9.2.2-Identifying-Outliers-Using-Z-Score-For-Minimum-Salary)
#           - [2.9.2.3 Identifying Outliers Using Z-Score For Salary Range](#2.9.2.3-Identifying-Outliers-Using-Z-Score-For-Salary-Range)
#           - [2.9.2.4 Removing Identified Outliers Using Z-Score Method](#2.9.2.4-Removing-Identified-Outliers-Using-Z-Score-Method)
#       - [2.9.3 Comparison of Outlier Identification & Removal](#2.9.3-Comparison-of-Outlier-Identification-&-Removal)
#           - [2.9.3.1 Description of IQR Method's Dataframe](#2.9.3.1-Description-of-IQR-Method's-Dataframe)
#           - [2.9.3.2 Description of Z-Score Method's Dataframe](#2.9.3.2-Description-of-Z-Score-Method's-Dataframe)
#       - [2.9.4 Conclusion of Method To Utilise](#2.9.4-Conclusion-of-Method-To-Utilise)
#     - [2.10 Validating Numerical Data](#2.10-Validating-Numerical-Data)
# - [3. Data Analysis and Visualisation](#3.-Data-Analysis-and-Visualisation)
#     - [3.1 Univariate Analysis](#3.1-Univariate-Analysis)
#       - [3.1.1 Job Posting Duration Analysis (Histogram)](#3.1.1-Job-Posting-Duration-Analysis-(Histogram))
#       - [3.1.2 Proportion of Remote Working (Pie Chart)](#3.1.2-Proportion-of-Remote-Working-(Pie-Chart))
#       - [3.1.3 Proportion of Viewers Who Applies (Pie Chart)](#3.1.3-Proportion-of-Viewers-Who-Applies-(Pie-Chart))
#     - [3.2 Bivariate Analysis](#3.2-Bivariate-Analysis)
#       - [3.2.1 Relationship Between Apply-to-View Ratio and Salary Range (Boxplot)](#3.2.1-Relationship-Between-Apply-to-View-Ratio-and-Salary-Range-(Boxplot))
#       - [3.2.2 Relationship Between Experience Level and Maximum Salary and Apply-to-View Ratio (Boxplot)](#3.2.2-Relationship-Between-Experience-Level-and-Maximum-Salary-and-Apply-to-View-Ratio-(Boxplot))
#       - [3.2.3 Proportion of Work Arrangement For Each Experience Levels (Stacked Bar Chart)](#3.2.3-Proportion-of-Work-Arrangement-For-Each-Experience-Levels-(Stacked-Bar-Chart))
#       - [3.2.4 Apply-to-View Ratio By Work Type (Bar Chart)](#3.2.4-Apply-to-View-Ratio-By-Work-Type-(Bar-Chart))
#       - [3.2.5 Apply-to-View Ratio Over Time (Line Chart)](#3.2.5-Apply-to-View-Ratio-Over-Time-(Line-Chart))
#
# - [4. Answering of Research Question](#4.-Answering-of-Research-Question)
#
# - [5. References](#5.-References)
