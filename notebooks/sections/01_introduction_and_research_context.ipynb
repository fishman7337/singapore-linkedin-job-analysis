# %% [markdown]
# <hr/>
# <h1>1. Introduction and Research Context</h1>

# %% [markdown]
# <p>In this section, I will be stating the purpose of the project and the objectives that should be achieved. I will also be stating the Research Question that I will be adopting and its relevance to the present day context.</p>

# %% [markdown]
# <hr/>
# <h2>1.1 Background Information</h2>

# %% [markdown]
# <p>The job market is a rapidly changing landscape that is influenced by many different factors. Some of these factor many include salary, flexibility, benefits, demand, etc. This creates huge competitions for both job-seekers and employers. To help both job-seekers and employers understand the current job market, the research question that will be formed later will have both the job-seekers' and the employers' interest accounted for. This will provide a hollistic point of view towards the current job market.</p>
# <br/>
# <p>An example of the rapidly changing After the COVID-19 pandemic, many job positions started to adopt a hybrid work arrangement which shifted the already rapidly changing situation of the job market. A research conducted by PwC in 2022 showed that 72% of Singaporeans prefer to have a hybrid work arrangement and 21% of Singaporeans prefer to have a remote work arrangement. These 2 work arrangement was unconventional before the COVID-19 pandemic but is now starting to become prominent. It is also important for employers to understand what its employeee and applicants wishes to adopt.</p>
# <br/>
# <p>The data analysis conducted here to answer the crafted research question hold paramount importance especially in Singapore as manpower is the greatest resources Singapore has. A research conducted by the Ministry of Manpower showed that Singapore's employment rate is 82.6% of the Labour Force. This shows a competitive job market where job visibility and application success are crucial for job seekers.</p>
# <br/>
# <p>Therefore, to smoothen the process of finding a job / posting a job in the rapidly changing job market, I will be performing data analysis on the datasets provided and subsequently, answer the research question crafted in the next sub-section.</p>

# %% [markdown]
# <hr/>
# <h2>1.2 Research Question</h2>

# %% [markdown]
# <p>The research question that I have formulate is stated below.</p>
# <br/>
# <p style="text-align:center;"><strong>What factors make job postings more visible and increase application rates, and how can job seekers use these insights to improve their job search?</strong></p>
# <br/>
# <p>This research question caters to both job seekers and employers which will require us to adopt a hollistic view of the data analytics. The relevance to both the job seekers and employers are stated below.</p>
# <br/>
# <p><strong><u>Job Seekers</u></strong></p>
# <ul>
#     <li>Helps them to understand what types of job posting gets the most attention.</li>
#     <li>Helps Job Seekers understand which job attributes leads to higher application rates, allowing them to target job postings with higher application rates that allign with their best interest. (e.g. Salary)</li>
#     <li>Allows Job Seekers to focus on job listing with higher demand, allowing them to save time and effort.</li>
# </ul>
# <p><strong><u>Employers</u></strong></p>
# <ul>
#     <li>Helps them to put up job postings that attracts competent candidates.</li>
#     <li>Helps Employers to idnetify and adjust factors that will lead to higher application results.</li>
# </ul>

# %% [markdown]
# <hr/>
# <h2>1.3 Research Objectives</h2>

# %% [markdown]
# <p><strong><u>List of Objectives to Complete to Answer Research Question</u></strong></p>
# <ul>
#     <li>Investigate factors influencing job posting views.</li>
#     <li>Explore relationships between application rates and different attributes.</li>
#     <li>Relationship between job posting views and application rates.</li>
#     <li>Identify which attribute are associated with high application rates and high views.</li>
#     <li>Provide data-driven recommendation for employers to optimise and adjust their job post.</li>
# </ul>
